# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bedd3b50d1dfa3ac8b7da6e62d8ce42a

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        current_description = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": current_description,
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | upernavik
# Processing Record 2 of Set 1 | shenjiamen
# Processing Record 3 of Set 1 | port alfred
# Processing Record 4 of Set 1 | sola
# Processing Record 5 of Set 1 | codrington
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | puerto ayora
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | dhidhdhoo
# Processing Record 10 of Set 1 | buraydah
# Processing Record 11 of Set 1 | cherskiy
# Processing Record 12 of Set 1 | chuy
# Processing Record 13 of Set 1 | huarmey
# Processing Record 14 of Set 1 | barrow
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | kavieng
# Processing Record 19 of Set 1 | south venice
# Processing Record 20 of Set 1 | bubaque
# Processing Record 21 of Set 1 | luganville
# Processing Record 22 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | zahirabad
# Processing Record 25 of Set 1 | port hardy
# Processing Record 26 of Set 1 | tezu
# Processing Record 27 of Set 1 | tasiilaq
# Processing Record 28 of Set 1 | kamaishi
# Processing Record 29 of Set 1 | georgetown
# Processing Record 30 of Set 1 | benghazi
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | luderitz
# Processing Record 33 of Set 1 | airai
# Processing Record 34 of Set 1 | port elizabeth
# Processing Record 35 of Set 1 | isangel
# Processing Record 36 of Set 1 | deputatskiy
# Processing Record 37 of Set 1 | neiafu
# Processing Record 38 of Set 1 | palasa
# Processing Record 39 of Set 1 | honiara
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | san ramon
# Processing Record 42 of Set 1 | bonthe
# Processing Record 43 of Set 1 | sur
# Processing Record 44 of Set 1 | kapaa
# Processing Record 45 of Set 1 | bardiyah
# Processing Record 46 of Set 1 | grindavik
# Processing Record 47 of Set 1 | elizabeth city
# Processing Record 48 of Set 1 | saldanha
# Processing Record 49 of Set 1 | qena
# Processing Record 50 of Set 1 | castro
# Processing Record 1 of Set 2 | sao filipe
# Processing Record 2 of Set 2 | umm kaddadah
# Processing Record 3 of Set 2 | victoria
# Processing Record 4 of Set 2 | chimbarongo
# Processing Record 5 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 2 | babanusah
# City not found. Skipping...
# Processing Record 7 of Set 2 | noumea
# Processing Record 8 of Set 2 | quelimane
# Processing Record 9 of Set 2 | gasa
# Processing Record 10 of Set 2 | tuatapere
# Processing Record 11 of Set 2 | requena
# Processing Record 12 of Set 2 | new norfolk
# Processing Record 13 of Set 2 | omsukchan
# Processing Record 14 of Set 2 | bambous virieux
# Processing Record 15 of Set 2 | alyangula
# Processing Record 16 of Set 2 | husavik
# Processing Record 17 of Set 2 | mataura
# Processing Record 18 of Set 2 | nikolskoye
# Processing Record 19 of Set 2 | haines junction
# Processing Record 20 of Set 2 | sijunjung
# Processing Record 21 of Set 2 | ahipara
# Processing Record 22 of Set 2 | simplicio mendes
# Processing Record 23 of Set 2 | tuktoyaktuk
# Processing Record 24 of Set 2 | vaini
# Processing Record 25 of Set 2 | sambava
# Processing Record 26 of Set 2 | ciudad bolivar
# Processing Record 27 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 2 | saint-joseph
# Processing Record 29 of Set 2 | atuona
# Processing Record 30 of Set 2 | lae
# Processing Record 31 of Set 2 | saint-philippe
# Processing Record 32 of Set 2 | moyale
# Processing Record 33 of Set 2 | hamilton
# Processing Record 34 of Set 2 | ribeira grande
# Processing Record 35 of Set 2 | moerai
# Processing Record 36 of Set 2 | hilo
# Processing Record 37 of Set 2 | broken hill
# Processing Record 38 of Set 2 | araure
# Processing Record 39 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 2 | lahaina
# Processing Record 41 of Set 2 | lianran
# Processing Record 42 of Set 2 | zhangye
# Processing Record 43 of Set 2 | naze
# Processing Record 44 of Set 2 | kieta
# Processing Record 45 of Set 2 | sayan
# Processing Record 46 of Set 2 | tautira
# Processing Record 47 of Set 2 | marzuq
# Processing Record 48 of Set 2 | ushuaia
# Processing Record 49 of Set 2 | tura
# Processing Record 50 of Set 2 | yeehaw junction
# City not found. Skipping...
# Processing Record 1 of Set 3 | khatanga
# Processing Record 2 of Set 3 | borborema
# Processing Record 3 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 3 | avarua
# Processing Record 5 of Set 3 | bredasdorp
# Processing Record 6 of Set 3 | hobart
# Processing Record 7 of Set 3 | vao
# Processing Record 8 of Set 3 | cape town
# Processing Record 9 of Set 3 | santa isabel do rio negro
# Processing Record 10 of Set 3 | rock sound
# Processing Record 11 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 3 | hermanus
# Processing Record 13 of Set 3 | bathsheba
# Processing Record 14 of Set 3 | longyearbyen
# Processing Record 15 of Set 3 | kulhudhuffushi
# Processing Record 16 of Set 3 | zapolyarnyy
# Processing Record 17 of Set 3 | nyimba
# Processing Record 18 of Set 3 | lamu
# Processing Record 19 of Set 3 | namibe
# Processing Record 20 of Set 3 | rongcheng
# Processing Record 21 of Set 3 | nome
# Processing Record 22 of Set 3 | chumikan
# Processing Record 23 of Set 3 | daxian
# City not found. Skipping...
# Processing Record 24 of Set 3 | san carlos de bariloche
# Processing Record 25 of Set 3 | okahandja
# Processing Record 26 of Set 3 | lakatoro
# Processing Record 27 of Set 3 | gizo
# Processing Record 28 of Set 3 | tual
# Processing Record 29 of Set 3 | paamiut
# Processing Record 30 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 31 of Set 3 | coahuayana
# Processing Record 32 of Set 3 | qaanaaq
# Processing Record 33 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 3 | salalah
# Processing Record 35 of Set 3 | nalut
# Processing Record 36 of Set 3 | pacific grove
# Processing Record 37 of Set 3 | faridan
# City not found. Skipping...
# Processing Record 38 of Set 3 | ahuimanu
# Processing Record 39 of Set 3 | mwingi
# Processing Record 40 of Set 3 | adrar
# Processing Record 41 of Set 3 | vilhena
# Processing Record 42 of Set 3 | sistranda
# Processing Record 43 of Set 3 | lafiagi
# Processing Record 44 of Set 3 | nanortalik
# Processing Record 45 of Set 3 | vagur
# Processing Record 46 of Set 3 | payo
# Processing Record 47 of Set 3 | shimoda
# Processing Record 48 of Set 3 | la rochelle
# Processing Record 49 of Set 3 | vostok
# Processing Record 50 of Set 3 | doha
# Processing Record 1 of Set 4 | mayor pablo lagerenza
# Processing Record 2 of Set 4 | tizimin
# Processing Record 3 of Set 4 | pangnirtung
# Processing Record 4 of Set 4 | kruisfontein
# Processing Record 5 of Set 4 | mar del plata
# Processing Record 6 of Set 4 | carnarvon
# Processing Record 7 of Set 4 | olhao
# Processing Record 8 of Set 4 | alice springs
# Processing Record 9 of Set 4 | darhan
# Processing Record 10 of Set 4 | wewak
# Processing Record 11 of Set 4 | higuey
# City not found. Skipping...
# Processing Record 12 of Set 4 | krupanj
# Processing Record 13 of Set 4 | nkhotakota
# Processing Record 14 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 4 | pemangkat
# Processing Record 16 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 4 | grand baie
# Processing Record 18 of Set 4 | yellowknife
# Processing Record 19 of Set 4 | san patricio
# Processing Record 20 of Set 4 | pskov
# Processing Record 21 of Set 4 | kavaratti
# Processing Record 22 of Set 4 | paita
# Processing Record 23 of Set 4 | lichinga
# Processing Record 24 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 4 | bom conselho
# Processing Record 26 of Set 4 | karcag
# Processing Record 27 of Set 4 | kingman
# Processing Record 28 of Set 4 | goderich
# Processing Record 29 of Set 4 | general jose eduvigis diaz
# Processing Record 30 of Set 4 | pevek
# Processing Record 31 of Set 4 | bethel
# Processing Record 32 of Set 4 | iqaluit
# Processing Record 33 of Set 4 | burns lake
# Processing Record 34 of Set 4 | lata
# Processing Record 35 of Set 4 | torbay
# Processing Record 36 of Set 4 | margate
# Processing Record 37 of Set 4 | tabou
# Processing Record 38 of Set 4 | raudeberg
# Processing Record 39 of Set 4 | lagoa
# Processing Record 40 of Set 4 | saskylakh
# Processing Record 41 of Set 4 | vokhtoga
# Processing Record 42 of Set 4 | mitchell
# Processing Record 43 of Set 4 | makakilo city
# Processing Record 44 of Set 4 | ponta do sol
# Processing Record 45 of Set 4 | poum
# Processing Record 46 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 4 | westport
# Processing Record 48 of Set 4 | bontang
# Processing Record 49 of Set 4 | olafsvik
# Processing Record 50 of Set 4 | werder
# Processing Record 1 of Set 5 | piacabucu
# Processing Record 2 of Set 5 | abu samrah
# Processing Record 3 of Set 5 | ulaangom
# Processing Record 4 of Set 5 | gimli
# Processing Record 5 of Set 5 | viedma
# Processing Record 6 of Set 5 | pestretsy
# Processing Record 7 of Set 5 | kirensk
# Processing Record 8 of Set 5 | hofn
# Processing Record 9 of Set 5 | thompson
# Processing Record 10 of Set 5 | thap than
# Processing Record 11 of Set 5 | okhotsk
# Processing Record 12 of Set 5 | faanui
# Processing Record 13 of Set 5 | alboraya
# Processing Record 14 of Set 5 | kidal
# Processing Record 15 of Set 5 | biu
# Processing Record 16 of Set 5 | evensk
# Processing Record 17 of Set 5 | senanga
# Processing Record 18 of Set 5 | mahebourg
# Processing Record 19 of Set 5 | namatanai
# Processing Record 20 of Set 5 | te anau
# Processing Record 21 of Set 5 | esperantina
# Processing Record 22 of Set 5 | esperance
# Processing Record 23 of Set 5 | vestmannaeyjar
# Processing Record 24 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 5 | dingle
# Processing Record 26 of Set 5 | provideniya
# Processing Record 27 of Set 5 | prince rupert
# Processing Record 28 of Set 5 | savannah bight
# Processing Record 29 of Set 5 | maraa
# Processing Record 30 of Set 5 | east london
# Processing Record 31 of Set 5 | clyde river
# Processing Record 32 of Set 5 | morant bay
# Processing Record 33 of Set 5 | ostrovnoy
# Processing Record 34 of Set 5 | diapaga
# Processing Record 35 of Set 5 | chokurdakh
# Processing Record 36 of Set 5 | dikson
# Processing Record 37 of Set 5 | linhares
# Processing Record 38 of Set 5 | narang
# Processing Record 39 of Set 5 | kaeo
# Processing Record 40 of Set 5 | sorland
# Processing Record 41 of Set 5 | nouadhibou
# Processing Record 42 of Set 5 | kodiak
# Processing Record 43 of Set 5 | grand gaube
# Processing Record 44 of Set 5 | mazyr
# Processing Record 45 of Set 5 | arraial do cabo
# Processing Record 46 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 5 | sakakah
# Processing Record 48 of Set 5 | norman wells
# Processing Record 49 of Set 5 | sao joao da barra
# Processing Record 50 of Set 5 | mionica
# Processing Record 1 of Set 6 | komsomolskiy
# Processing Record 2 of Set 6 | san vicente
# Processing Record 3 of Set 6 | mackenzie
# Processing Record 4 of Set 6 | fernie
# Processing Record 5 of Set 6 | reefton
# City not found. Skipping...
# Processing Record 6 of Set 6 | kloulklubed
# Processing Record 7 of Set 6 | batagay-alyta
# Processing Record 8 of Set 6 | businga
# Processing Record 9 of Set 6 | butaritari
# Processing Record 10 of Set 6 | hami
# Processing Record 11 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 12 of Set 6 | akdepe
# Processing Record 13 of Set 6 | sioux lookout
# Processing Record 14 of Set 6 | eureka
# Processing Record 15 of Set 6 | shahpura
# Processing Record 16 of Set 6 | sitka
# Processing Record 17 of Set 6 | lompoc
# Processing Record 18 of Set 6 | guadix
# Processing Record 19 of Set 6 | geraldton
# Processing Record 20 of Set 6 | jieshi
# Processing Record 21 of Set 6 | aguimes
# Processing Record 22 of Set 6 | baryshivka
# Processing Record 23 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 24 of Set 6 | constitucion
# Processing Record 25 of Set 6 | itoman
# Processing Record 26 of Set 6 | fort nelson
# Processing Record 27 of Set 6 | kardailovo
# Processing Record 28 of Set 6 | hearst
# Processing Record 29 of Set 6 | klyuchi
# Processing Record 30 of Set 6 | mehamn
# Processing Record 31 of Set 6 | camacupa
# Processing Record 32 of Set 6 | micheweni
# Processing Record 33 of Set 6 | gobabis
# Processing Record 34 of Set 6 | santa cruz de tenerife
# Processing Record 35 of Set 6 | alta floresta
# Processing Record 36 of Set 6 | saint anthony
# Processing Record 37 of Set 6 | mountain home
# Processing Record 38 of Set 6 | cordoba
# Processing Record 39 of Set 6 | santa marta
# Processing Record 40 of Set 6 | arona
# Processing Record 41 of Set 6 | shestakovo
# Processing Record 42 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 6 | lebu
# Processing Record 44 of Set 6 | lorengau
# Processing Record 45 of Set 6 | mailani
# Processing Record 46 of Set 6 | chapais
# Processing Record 47 of Set 6 | san cristobal
# Processing Record 48 of Set 6 | plettenberg bay
# Processing Record 49 of Set 6 | santa cruz
# Processing Record 50 of Set 6 | vangaindrano
# Processing Record 1 of Set 7 | henties bay
# Processing Record 2 of Set 7 | fortuna
# Processing Record 3 of Set 7 | mulege
# Processing Record 4 of Set 7 | sarakhs
# Processing Record 5 of Set 7 | ambulu
# Processing Record 6 of Set 7 | takoradi
# Processing Record 7 of Set 7 | yeppoon
# Processing Record 8 of Set 7 | auki
# Processing Record 9 of Set 7 | mount gambier
# Processing Record 10 of Set 7 | banda aceh
# Processing Record 11 of Set 7 | pisco
# Processing Record 12 of Set 7 | kirakira
# Processing Record 13 of Set 7 | baijiantan
# Processing Record 14 of Set 7 | trinidad
# Processing Record 15 of Set 7 | sukhoverkovo
# City not found. Skipping...
# Processing Record 16 of Set 7 | saint george
# Processing Record 17 of Set 7 | orlik
# Processing Record 18 of Set 7 | makung
# City not found. Skipping...
# Processing Record 19 of Set 7 | krasnoye
# Processing Record 20 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 7 | tiksi
# Processing Record 22 of Set 7 | berea
# Processing Record 23 of Set 7 | katha
# City not found. Skipping...
# Processing Record 24 of Set 7 | aleysk
# Processing Record 25 of Set 7 | leningradskiy
# Processing Record 26 of Set 7 | aripuana
# Processing Record 27 of Set 7 | mount isa
# Processing Record 28 of Set 7 | puyang
# Processing Record 29 of Set 7 | boffa
# Processing Record 30 of Set 7 | ugoofaaru
# Processing Record 31 of Set 7 | suzu
# City not found. Skipping...
# Processing Record 32 of Set 7 | de-kastri
# Processing Record 33 of Set 7 | cidreira
# Processing Record 34 of Set 7 | nizwa
# Processing Record 35 of Set 7 | port said
# Processing Record 36 of Set 7 | merke
# Processing Record 37 of Set 7 | ossora
# Processing Record 38 of Set 7 | vila velha
# Processing Record 39 of Set 7 | fairbanks
# Processing Record 40 of Set 7 | severo-kurilsk
# Processing Record 41 of Set 7 | haverfordwest
# Processing Record 42 of Set 7 | burica
# City not found. Skipping...
# Processing Record 43 of Set 7 | ozernovskiy
# Processing Record 44 of Set 7 | vardo
# Processing Record 45 of Set 7 | krivosheino
# Processing Record 46 of Set 7 | tudela
# Processing Record 47 of Set 7 | laukaa
# Processing Record 48 of Set 7 | buala
# Processing Record 49 of Set 7 | dauphin
# Processing Record 50 of Set 7 | nagorsk
# Processing Record 1 of Set 8 | fare
# Processing Record 2 of Set 8 | santa ines
# Processing Record 3 of Set 8 | imeni babushkina
# Processing Record 4 of Set 8 | bengkulu
# Processing Record 5 of Set 8 | liwale
# Processing Record 6 of Set 8 | meadow lake
# Processing Record 7 of Set 8 | tanout
# Processing Record 8 of Set 8 | inuvik
# Processing Record 9 of Set 8 | korem
# Processing Record 10 of Set 8 | hewitt
# Processing Record 11 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 12 of Set 8 | rapid valley
# Processing Record 13 of Set 8 | shingu
# Processing Record 14 of Set 8 | coihaique
# Processing Record 15 of Set 8 | iglesias
# Processing Record 16 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 17 of Set 8 | coromandel
# Processing Record 18 of Set 8 | abalak
# Processing Record 19 of Set 8 | kahului
# Processing Record 20 of Set 8 | morondava
# Processing Record 21 of Set 8 | kang
# Processing Record 22 of Set 8 | ponta delgada
# Processing Record 23 of Set 8 | kutum
# Processing Record 24 of Set 8 | touros
# Processing Record 25 of Set 8 | sao miguel do araguaia
# Processing Record 26 of Set 8 | altay
# Processing Record 27 of Set 8 | katobu
# Processing Record 28 of Set 8 | otradnoye
# Processing Record 29 of Set 8 | cinisi
# Processing Record 30 of Set 8 | tocopilla
# Processing Record 31 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 32 of Set 8 | leh
# Processing Record 33 of Set 8 | oranjestad
# Processing Record 34 of Set 8 | loa janan
# Processing Record 35 of Set 8 | chokwe
# Processing Record 36 of Set 8 | daru
# Processing Record 37 of Set 8 | bury saint edmunds
# City not found. Skipping...
# Processing Record 38 of Set 8 | khurba
# Processing Record 39 of Set 8 | dawson creek
# Processing Record 40 of Set 8 | strezhevoy
# Processing Record 41 of Set 8 | novaya bryan
# Processing Record 42 of Set 8 | atar
# Processing Record 43 of Set 8 | san ignacio
# Processing Record 44 of Set 8 | kuching
# Processing Record 45 of Set 8 | quchan
# Processing Record 46 of Set 8 | cap malheureux
# Processing Record 47 of Set 8 | berlevag
# Processing Record 48 of Set 8 | klaksvik
# Processing Record 49 of Set 8 | yaan
# Processing Record 50 of Set 8 | boras
# Processing Record 1 of Set 9 | kelvington
# Processing Record 2 of Set 9 | sao gabriel da cachoeira
# Processing Record 3 of Set 9 | freetown
# Processing Record 4 of Set 9 | estelle
# Processing Record 5 of Set 9 | korla
# Processing Record 6 of Set 9 | marystown
# Processing Record 7 of Set 9 | conceicao da barra
# Processing Record 8 of Set 9 | amparafaravola
# Processing Record 9 of Set 9 | dudinka
# Processing Record 10 of Set 9 | swan river
# Processing Record 11 of Set 9 | ancud
# Processing Record 12 of Set 9 | harnosand
# Processing Record 13 of Set 9 | bhimunipatnam
# Processing Record 14 of Set 9 | portland
# Processing Record 15 of Set 9 | ambon
# Processing Record 16 of Set 9 | cooma
# Processing Record 17 of Set 9 | tazovskiy
# Processing Record 18 of Set 9 | kaitangata
# Processing Record 19 of Set 9 | narsaq
# Processing Record 20 of Set 9 | richards bay
# Processing Record 21 of Set 9 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 22 of Set 9 | hienghene
# Processing Record 23 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 24 of Set 9 | aklavik
# Processing Record 25 of Set 9 | cayenne
# Processing Record 26 of Set 9 | monrovia
# Processing Record 27 of Set 9 | puerto penasco
# Processing Record 28 of Set 9 | katsuura
# Processing Record 29 of Set 9 | tolmezzo
# Processing Record 30 of Set 9 | cabo san lucas
# Processing Record 31 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 9 | kununurra
# Processing Record 33 of Set 9 | souillac
# Processing Record 34 of Set 9 | saint-augustin
# Processing Record 35 of Set 9 | patnagarh
# Processing Record 36 of Set 9 | bitung
# Processing Record 37 of Set 9 | ban nahin
# Processing Record 38 of Set 9 | tiszabo
# Processing Record 39 of Set 9 | trelew
# Processing Record 40 of Set 9 | yar-sale
# Processing Record 41 of Set 9 | krasnoselkup
# Processing Record 42 of Set 9 | asau
# Processing Record 43 of Set 9 | mahibadhoo
# Processing Record 44 of Set 9 | rocha
# Processing Record 45 of Set 9 | ilulissat
# Processing Record 46 of Set 9 | dera ghazi khan
# Processing Record 47 of Set 9 | kankon
# Processing Record 48 of Set 9 | carutapera
# Processing Record 49 of Set 9 | ramla
# Processing Record 50 of Set 9 | bandarbeyla
# Processing Record 1 of Set 10 | sheridan
# Processing Record 2 of Set 10 | lavrentiya
# Processing Record 3 of Set 10 | nazarovo
# Processing Record 4 of Set 10 | goya
# Processing Record 5 of Set 10 | emerald
# Processing Record 6 of Set 10 | mufulira
# Processing Record 7 of Set 10 | gijon
# Processing Record 8 of Set 10 | pospelikha
# Processing Record 9 of Set 10 | bairiki
# Processing Record 10 of Set 10 | hasaki
# Processing Record 11 of Set 10 | madera
# Processing Record 12 of Set 10 | blackwater
# Processing Record 13 of Set 10 | inhambane
# Processing Record 14 of Set 10 | thunder bay
# Processing Record 15 of Set 10 | la ronge
# Processing Record 16 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 10 | aksu
# Processing Record 18 of Set 10 | srednekolymsk
# Processing Record 19 of Set 10 | petatlan
# Processing Record 20 of Set 10 | pinawa
# Processing Record 21 of Set 10 | phuthaditjhaba
# Processing Record 22 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 23 of Set 10 | pak phanang
# Processing Record 24 of Set 10 | ughelli
# Processing Record 25 of Set 10 | sao jose da coroa grande
# Processing Record 26 of Set 10 | vernon
# Processing Record 27 of Set 10 | ilo
# Processing Record 28 of Set 10 | mitrofanovka
# Processing Record 29 of Set 10 | beringovskiy
# Processing Record 30 of Set 10 | gazli
# Processing Record 31 of Set 10 | bud
# Processing Record 32 of Set 10 | likasi
# Processing Record 33 of Set 10 | isselburg
# Processing Record 34 of Set 10 | koulikoro
# Processing Record 35 of Set 10 | bahia blanca
# Processing Record 36 of Set 10 | sinnamary
# Processing Record 37 of Set 10 | college
# Processing Record 38 of Set 10 | rio gallegos
# Processing Record 39 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 40 of Set 10 | temir
# Processing Record 41 of Set 10 | mubi
# Processing Record 42 of Set 10 | wanaka
# Processing Record 43 of Set 10 | boysun
# Processing Record 44 of Set 10 | estreito
# Processing Record 45 of Set 10 | san matias
# Processing Record 46 of Set 10 | ust-kalmanka
# Processing Record 47 of Set 10 | port lincoln
# Processing Record 48 of Set 10 | antofagasta
# Processing Record 49 of Set 10 | nantucket
# Processing Record 50 of Set 10 | los llanos de aridane
# Processing Record 1 of Set 11 | laguna
# Processing Record 2 of Set 11 | wajima
# Processing Record 3 of Set 11 | fredericton
# Processing Record 4 of Set 11 | puerto escondido
# Processing Record 5 of Set 11 | bahar
# Processing Record 6 of Set 11 | lisakovsk
# Processing Record 7 of Set 11 | noyabrsk
# Processing Record 8 of Set 11 | kodinsk
# Processing Record 9 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 10 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 11 | maniitsoq
# Processing Record 12 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 13 of Set 11 | papenburg
# Processing Record 14 of Set 11 | omboue
# Processing Record 15 of Set 11 | guerrero negro
# Processing Record 16 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 11 | natchitoches
# Processing Record 18 of Set 11 | krasnaya gorbatka
# Processing Record 19 of Set 11 | salekhard
# Processing Record 20 of Set 11 | hokitika
# Processing Record 21 of Set 11 | comodoro rivadavia
# Processing Record 22 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 23 of Set 11 | boden
# Processing Record 24 of Set 11 | sisimiut
# Processing Record 25 of Set 11 | taneatua
# City not found. Skipping...
# Processing Record 26 of Set 11 | pitimbu
# Processing Record 27 of Set 11 | tobati
# Processing Record 28 of Set 11 | qasigiannguit
# Processing Record 29 of Set 11 | imbituba
# Processing Record 30 of Set 11 | mindelo
# Processing Record 31 of Set 11 | cururupu
# Processing Record 32 of Set 11 | sobolevo
# Processing Record 33 of Set 11 | camacha
# Processing Record 34 of Set 11 | santiago tuxtla
# Processing Record 35 of Set 11 | tymoshivka
# Processing Record 36 of Set 11 | dvinskoy
# Processing Record 37 of Set 11 | anadyr
# Processing Record 38 of Set 11 | verkhnevilyuysk
# Processing Record 39 of Set 11 | kapit
# Processing Record 40 of Set 11 | kindu
# Processing Record 41 of Set 11 | salisbury
# Processing Record 42 of Set 11 | pangai
# Processing Record 43 of Set 11 | arvika
# Processing Record 44 of Set 11 | athabasca
# Processing Record 45 of Set 11 | sebrovo
# Processing Record 46 of Set 11 | giovinazzo
# Processing Record 47 of Set 11 | hualmay
# Processing Record 48 of Set 11 | karwar
# Processing Record 49 of Set 11 | placido de castro
# Processing Record 50 of Set 11 | dujuma
# City not found. Skipping...
# Processing Record 1 of Set 12 | celestun
# Processing Record 2 of Set 12 | epernay
# Processing Record 3 of Set 12 | letnyaya stavka
# Processing Record 4 of Set 12 | pavlodar
# Processing Record 5 of Set 12 | zabol
# Processing Record 6 of Set 12 | kargopol
# Processing Record 7 of Set 12 | bose
# Processing Record 8 of Set 12 | neuquen
# Processing Record 9 of Set 12 | birjand
# Processing Record 10 of Set 12 | sidney
# Processing Record 11 of Set 12 | bambanglipuro
# Processing Record 12 of Set 12 | qaqortoq
# Processing Record 13 of Set 12 | vicuna
# Processing Record 14 of Set 12 | port blair
# Processing Record 15 of Set 12 | mandalgovi
# Processing Record 16 of Set 12 | sedelnikovo
# City not found. Skipping...
# Processing Record 17 of Set 12 | singaraja
# Processing Record 18 of Set 12 | rupert
# Processing Record 19 of Set 12 | buchanan
# Processing Record 20 of Set 12 | belmonte
# Processing Record 21 of Set 12 | burnie
# Processing Record 22 of Set 12 | ushtobe
# Processing Record 23 of Set 12 | kokopo
# Processing Record 24 of Set 12 | bilma
# Processing Record 25 of Set 12 | nova odesa
# Processing Record 26 of Set 12 | pachino
# Processing Record 27 of Set 12 | tabas
# Processing Record 28 of Set 12 | high prairie
# Processing Record 29 of Set 12 | helena
# Processing Record 30 of Set 12 | ocara
# Processing Record 31 of Set 12 | yulara
# Processing Record 32 of Set 12 | kyzyl-suu
# Processing Record 33 of Set 12 | mabaruma
# Processing Record 34 of Set 12 | fairlie
# Processing Record 35 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 36 of Set 12 | havoysund
# Processing Record 37 of Set 12 | campos belos
# Processing Record 38 of Set 12 | karaton
# Processing Record 39 of Set 12 | emba
# Processing Record 40 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 41 of Set 12 | constantine
# Processing Record 42 of Set 12 | mojo
# Processing Record 43 of Set 12 | balakhninskiy
# Processing Record 44 of Set 12 | poso
# Processing Record 45 of Set 12 | hambantota
# Processing Record 46 of Set 12 | abu kamal
# Processing Record 47 of Set 12 | dharchula
# Processing Record 48 of Set 12 | pucallpa
# Processing Record 49 of Set 12 | bembereke
# Processing Record 50 of Set 12 | santander
# Processing Record 1 of Set 13 | sovetskiy
# Processing Record 2 of Set 13 | khani
# Processing Record 3 of Set 13 | zhezkazgan
# Processing Record 4 of Set 13 | puteyets
# Processing Record 5 of Set 13 | port-gentil
# Processing Record 6 of Set 13 | mbandaka
# Processing Record 7 of Set 13 | sinkat
# City not found. Skipping...
# Processing Record 8 of Set 13 | mapiripan
# Processing Record 9 of Set 13 | namie
# Processing Record 10 of Set 13 | minsk
# Processing Record 11 of Set 13 | santa barbara
# Processing Record 12 of Set 13 | harboore
# Processing Record 13 of Set 13 | luanda
# Processing Record 14 of Set 13 | erdaojiang
# Processing Record 15 of Set 13 | male
# Processing Record 16 of Set 13 | kajaani
# Processing Record 17 of Set 13 | port hedland
# Processing Record 18 of Set 13 | sabha
# Processing Record 19 of Set 13 | pacatuba
# Processing Record 20 of Set 13 | alofi
# Processing Record 21 of Set 13 | hashtrud
# Processing Record 22 of Set 13 | bonavista
# Processing Record 23 of Set 13 | itarema
# Processing Record 24 of Set 13 | bouca
# Processing Record 25 of Set 13 | santiago de chuco
# Processing Record 26 of Set 13 | caravelas
# Processing Record 27 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 13 | pimentel
# Processing Record 29 of Set 13 | macaboboni
# City not found. Skipping...
# Processing Record 30 of Set 13 | kati
# Processing Record 31 of Set 13 | thinadhoo
# Processing Record 32 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 33 of Set 13 | zhigansk
# Processing Record 34 of Set 13 | kerki
# City not found. Skipping...
# Processing Record 35 of Set 13 | selma
# Processing Record 36 of Set 13 | gamba
# Processing Record 37 of Set 13 | san rafael del sur
# Processing Record 38 of Set 13 | cullinan
# Processing Record 39 of Set 13 | warrnambool
# Processing Record 40 of Set 13 | coro
# Processing Record 41 of Set 13 | mudgee
# Processing Record 42 of Set 13 | saint-leu
# Processing Record 43 of Set 13 | gat
# Processing Record 44 of Set 13 | lalomanu
# City not found. Skipping...
# Processing Record 45 of Set 13 | at-bashi
# Processing Record 46 of Set 13 | zeya
# Processing Record 47 of Set 13 | diamantino
# Processing Record 48 of Set 13 | agara
# Processing Record 49 of Set 13 | ust-kuyga
# Processing Record 50 of Set 13 | hanna
# Processing Record 1 of Set 14 | varnavino
# Processing Record 2 of Set 14 | flinders
# Processing Record 3 of Set 14 | jiangyou
# Processing Record 4 of Set 14 | xai-xai
# Processing Record 5 of Set 14 | ilhabela
# Processing Record 6 of Set 14 | lagos
# Processing Record 7 of Set 14 | dakar
# Processing Record 8 of Set 14 | anloga
# Processing Record 9 of Set 14 | natal
# Processing Record 10 of Set 14 | nuuk
# Processing Record 11 of Set 14 | nyurba
# Processing Record 12 of Set 14 | mayo
# Processing Record 13 of Set 14 | tombouctou
# Processing Record 14 of Set 14 | vanavara
# Processing Record 15 of Set 14 | zhuhai
# Processing Record 16 of Set 14 | magadan
# Processing Record 17 of Set 14 | arlit
# Processing Record 18 of Set 14 | bossier city
# Processing Record 19 of Set 14 | batticaloa
# Processing Record 20 of Set 14 | yatou
# Processing Record 21 of Set 14 | marsabit
# Processing Record 22 of Set 14 | puerto suarez
# Processing Record 23 of Set 14 | anshun
# Processing Record 24 of Set 14 | lamesa
# Processing Record 25 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 26 of Set 14 | harrison
# Processing Record 27 of Set 14 | saint-francois
# Processing Record 28 of Set 14 | krasnyy chikoy
# Processing Record 29 of Set 14 | kiama
# Processing Record 30 of Set 14 | pleasant point
# Processing Record 31 of Set 14 | turtas
# Processing Record 32 of Set 14 | greensburg
# Processing Record 33 of Set 14 | gravdal
# Processing Record 34 of Set 14 | barentu
# Processing Record 35 of Set 14 | pierre
# Processing Record 36 of Set 14 | beaverlodge
# Processing Record 37 of Set 14 | kudahuvadhoo
# Processing Record 38 of Set 14 | cascais
# Processing Record 39 of Set 14 | marion
# Processing Record 40 of Set 14 | puri
# Processing Record 41 of Set 14 | santana
# Processing Record 42 of Set 14 | tamiahua
# Processing Record 43 of Set 14 | lumding
# Processing Record 44 of Set 14 | outram
# Processing Record 45 of Set 14 | vila franca do campo
# Processing Record 46 of Set 14 | hunza
# City not found. Skipping...
# Processing Record 47 of Set 14 | nelson bay
# Processing Record 48 of Set 14 | joshimath
# Processing Record 49 of Set 14 | taoudenni
# Processing Record 50 of Set 14 | horsham
# Processing Record 1 of Set 15 | one hundred mile house
# City not found. Skipping...
# Processing Record 2 of Set 15 | synya
# Processing Record 3 of Set 15 | braganca
# Processing Record 4 of Set 15 | brae
# Processing Record 5 of Set 15 | canavieiras
# Processing Record 6 of Set 15 | gillette
# Processing Record 7 of Set 15 | matagami
# Processing Record 8 of Set 15 | marienburg
# Processing Record 9 of Set 15 | la rioja
# Processing Record 10 of Set 15 | novo aripuana
# Processing Record 11 of Set 15 | khorramshahr
# Processing Record 12 of Set 15 | khairagarh
# Processing Record 13 of Set 15 | cockburn town
# Processing Record 14 of Set 15 | truth or consequences
# Processing Record 15 of Set 15 | whyalla
# Processing Record 16 of Set 15 | roald
# Processing Record 17 of Set 15 | tigil
# Processing Record 18 of Set 15 | ambunti
# Processing Record 19 of Set 15 | sao felix do xingu
# Processing Record 20 of Set 15 | axim
# Processing Record 21 of Set 15 | dunedin
# Processing Record 22 of Set 15 | medina
# Processing Record 23 of Set 15 | talaya
# Processing Record 24 of Set 15 | labuan
# Processing Record 25 of Set 15 | faya
# Processing Record 26 of Set 15 | rafai
# Processing Record 27 of Set 15 | mutoko
# Processing Record 28 of Set 15 | jalu
# Processing Record 29 of Set 15 | jizan
# Processing Record 30 of Set 15 | mehran
# Processing Record 31 of Set 15 | kikwit
# Processing Record 32 of Set 15 | barra dos coqueiros
# Processing Record 33 of Set 15 | kandrian
# Processing Record 34 of Set 15 | kenai
# Processing Record 35 of Set 15 | russell
# Processing Record 36 of Set 15 | nemuro
# Processing Record 37 of Set 15 | nizhniy tsasuchey
# Processing Record 38 of Set 15 | panalingaan
# Processing Record 39 of Set 15 | moose factory
# Processing Record 40 of Set 15 | sibut
# Processing Record 41 of Set 15 | muros
# Processing Record 42 of Set 15 | stafford
# Processing Record 43 of Set 15 | uray
# Processing Record 44 of Set 15 | sjenica
# Processing Record 45 of Set 15 | iracoubo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_weather_df = pd.DataFrame(city_data)
city_weather_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Upernavik      GL  72.7868  -56.1549     15.19        95         100
# 1   Shenjiamen      CN  29.9576  122.2980     54.59        58           0
# 2  Port Alfred      ZA -33.5906   26.8910     80.96        73          73
# 3         Sola      VU -13.8833  167.5500     86.00        84          75
# 4   Codrington      AU -38.2667  141.9667     59.11        67          37
#
#    Wind Speed Current Description
# 0        4.65     overcast clouds
# 1        9.53           clear sky
# 2       13.24       broken clouds
# 3        4.56       broken clouds
# 4       26.96    scattered clouds

# %%
city_weather_df.to_csv('WeatherPy_Database.csv,')

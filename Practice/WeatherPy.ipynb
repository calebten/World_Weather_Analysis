# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

# Import the time module.
import time

# Import the datetime module from the datetime library.
from datetime import datetime

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the API key.
from config import weather_api_key

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 591

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
              
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
    
    # If an error is experienced, skip the city.
    except:
        # traceback.print_exc()
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

# city_data.head()
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | ponta do sol
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | nenjiang
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 1 | theunissen
# Processing Record 8 of Set 1 | nantucket
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | nikolskoye
# Processing Record 11 of Set 1 | sidney
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | avarua
# Processing Record 14 of Set 1 | hunza
# City not found. Skipping...
# Processing Record 15 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | luzhou
# Processing Record 18 of Set 1 | bambous virieux
# Processing Record 19 of Set 1 | beringovskiy
# Processing Record 20 of Set 1 | new norfolk
# Processing Record 21 of Set 1 | jega
# Processing Record 22 of Set 1 | pangnirtung
# Processing Record 23 of Set 1 | goderich
# Processing Record 24 of Set 1 | cabo san lucas
# Processing Record 25 of Set 1 | ahipara
# Processing Record 26 of Set 1 | bilibino
# Processing Record 27 of Set 1 | chokurdakh
# Processing Record 28 of Set 1 | dali
# Processing Record 29 of Set 1 | port alfred
# Processing Record 30 of Set 1 | longyearbyen
# Processing Record 31 of Set 1 | shingu
# Processing Record 32 of Set 1 | upernavik
# Processing Record 33 of Set 1 | butaritari
# Processing Record 34 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | mar del plata
# Processing Record 37 of Set 1 | kapaa
# Processing Record 38 of Set 1 | fairbanks
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | hilo
# Processing Record 41 of Set 1 | faya
# Processing Record 42 of Set 1 | tulum
# Processing Record 43 of Set 1 | san miguel de cauri
# Processing Record 44 of Set 1 | mumford
# Processing Record 45 of Set 1 | kununurra
# Processing Record 46 of Set 1 | castro
# Processing Record 47 of Set 1 | saryshagan
# City not found. Skipping...
# Processing Record 48 of Set 1 | luderitz
# Processing Record 49 of Set 1 | airai
# Processing Record 50 of Set 1 | charters towers
# Processing Record 1 of Set 2 | clyde river
# Processing Record 2 of Set 2 | taltal
# Processing Record 3 of Set 2 | tasiilaq
# Processing Record 4 of Set 2 | awjilah
# Processing Record 5 of Set 2 | udachnyy
# Processing Record 6 of Set 2 | hobart
# Processing Record 7 of Set 2 | karratha
# Processing Record 8 of Set 2 | bluff
# Processing Record 9 of Set 2 | puerto ayora
# Processing Record 10 of Set 2 | nyurba
# Processing Record 11 of Set 2 | moose factory
# Processing Record 12 of Set 2 | samarai
# Processing Record 13 of Set 2 | talnakh
# Processing Record 14 of Set 2 | bethel
# Processing Record 15 of Set 2 | luwuk
# Processing Record 16 of Set 2 | berlevag
# Processing Record 17 of Set 2 | carnarvon
# Processing Record 18 of Set 2 | saskylakh
# Processing Record 19 of Set 2 | ushuaia
# Processing Record 20 of Set 2 | gonda
# Processing Record 21 of Set 2 | mpongwe
# Processing Record 22 of Set 2 | kastamonu
# Processing Record 23 of Set 2 | hithadhoo
# Processing Record 24 of Set 2 | salalah
# Processing Record 25 of Set 2 | mount gambier
# Processing Record 26 of Set 2 | saint-philippe
# Processing Record 27 of Set 2 | praia da vitoria
# Processing Record 28 of Set 2 | samana
# Processing Record 29 of Set 2 | jamestown
# Processing Record 30 of Set 2 | cherskiy
# Processing Record 31 of Set 2 | yellowknife
# Processing Record 32 of Set 2 | krasnoye
# Processing Record 33 of Set 2 | zhigansk
# Processing Record 34 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 2 | cidreira
# Processing Record 36 of Set 2 | tuktoyaktuk
# Processing Record 37 of Set 2 | lorengau
# Processing Record 38 of Set 2 | sambava
# Processing Record 39 of Set 2 | abu samrah
# Processing Record 40 of Set 2 | umm lajj
# Processing Record 41 of Set 2 | akureyri
# Processing Record 42 of Set 2 | ambulu
# Processing Record 43 of Set 2 | dikson
# Processing Record 44 of Set 2 | atuona
# Processing Record 45 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 2 | mahebourg
# Processing Record 47 of Set 2 | tromso
# Processing Record 48 of Set 2 | boende
# Processing Record 49 of Set 2 | sisophon
# Processing Record 50 of Set 2 | sorland
# Processing Record 1 of Set 3 | arman
# Processing Record 2 of Set 3 | khatanga
# Processing Record 3 of Set 3 | esperance
# Processing Record 4 of Set 3 | mazamari
# Processing Record 5 of Set 3 | sri aman
# Processing Record 6 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 3 | kaitangata
# Processing Record 8 of Set 3 | olafsvik
# Processing Record 9 of Set 3 | zhangjiakou
# Processing Record 10 of Set 3 | sept-iles
# Processing Record 11 of Set 3 | peachland
# Processing Record 12 of Set 3 | utiroa
# City not found. Skipping...
# Processing Record 13 of Set 3 | parrita
# Processing Record 14 of Set 3 | vila franca do campo
# Processing Record 15 of Set 3 | kenai
# Processing Record 16 of Set 3 | florianopolis
# Processing Record 17 of Set 3 | port hawkesbury
# Processing Record 18 of Set 3 | fortuna
# Processing Record 19 of Set 3 | bredasdorp
# Processing Record 20 of Set 3 | kieta
# Processing Record 21 of Set 3 | filiatra
# Processing Record 22 of Set 3 | ancud
# Processing Record 23 of Set 3 | bengkulu
# Processing Record 24 of Set 3 | wad madani
# Processing Record 25 of Set 3 | hasaki
# Processing Record 26 of Set 3 | barentu
# Processing Record 27 of Set 3 | northam
# Processing Record 28 of Set 3 | shimoda
# Processing Record 29 of Set 3 | saint george
# Processing Record 30 of Set 3 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 31 of Set 3 | leningradskiy
# Processing Record 32 of Set 3 | garissa
# Processing Record 33 of Set 3 | ye
# City not found. Skipping...
# Processing Record 34 of Set 3 | iqaluit
# Processing Record 35 of Set 3 | vastervik
# City not found. Skipping...
# Processing Record 36 of Set 3 | farafangana
# Processing Record 37 of Set 3 | zheshart
# Processing Record 38 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 3 | kodiak
# Processing Record 40 of Set 3 | hermanus
# Processing Record 41 of Set 3 | arraial do cabo
# Processing Record 42 of Set 3 | slave lake
# Processing Record 43 of Set 3 | comodoro rivadavia
# Processing Record 44 of Set 3 | sao joao da barra
# Processing Record 45 of Set 3 | rubizhne
# Processing Record 46 of Set 3 | hanko
# Processing Record 47 of Set 3 | narsaq
# Processing Record 48 of Set 3 | kinanah
# City not found. Skipping...
# Processing Record 49 of Set 3 | bose
# Processing Record 50 of Set 3 | lebu
# Processing Record 1 of Set 4 | tautira
# Processing Record 2 of Set 4 | hobyo
# Processing Record 3 of Set 4 | ahlat
# Processing Record 4 of Set 4 | ayr
# Processing Record 5 of Set 4 | san julian
# Processing Record 6 of Set 4 | grieskirchen
# Processing Record 7 of Set 4 | yilan
# Processing Record 8 of Set 4 | ballina
# Processing Record 9 of Set 4 | moron
# Processing Record 10 of Set 4 | ukiah
# Processing Record 11 of Set 4 | haines junction
# Processing Record 12 of Set 4 | hermosillo
# Processing Record 13 of Set 4 | vila velha
# Processing Record 14 of Set 4 | souillac
# Processing Record 15 of Set 4 | tomatlan
# Processing Record 16 of Set 4 | provideniya
# Processing Record 17 of Set 4 | spirit river
# Processing Record 18 of Set 4 | norman wells
# Processing Record 19 of Set 4 | victoria
# Processing Record 20 of Set 4 | guerrero negro
# Processing Record 21 of Set 4 | bathsheba
# Processing Record 22 of Set 4 | canchungo
# Processing Record 23 of Set 4 | kamyshla
# Processing Record 24 of Set 4 | koumac
# Processing Record 25 of Set 4 | portland
# Processing Record 26 of Set 4 | tahta
# Processing Record 27 of Set 4 | port keats
# Processing Record 28 of Set 4 | whitehorse
# Processing Record 29 of Set 4 | tolaga bay
# Processing Record 30 of Set 4 | makarov
# Processing Record 31 of Set 4 | gari
# Processing Record 32 of Set 4 | saint-pierre
# Processing Record 33 of Set 4 | qaanaaq
# Processing Record 34 of Set 4 | itarema
# Processing Record 35 of Set 4 | robertson
# Processing Record 36 of Set 4 | kruisfontein
# Processing Record 37 of Set 4 | ribeira grande
# Processing Record 38 of Set 4 | faanui
# Processing Record 39 of Set 4 | kutum
# Processing Record 40 of Set 4 | lompoc
# Processing Record 41 of Set 4 | mullaitivu
# City not found. Skipping...
# Processing Record 42 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 4 | morden
# Processing Record 44 of Set 4 | asfi
# Processing Record 45 of Set 4 | richards bay
# Processing Record 46 of Set 4 | kaeo
# Processing Record 47 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 48 of Set 4 | coxim
# Processing Record 49 of Set 4 | duobao
# Processing Record 50 of Set 4 | touros
# Processing Record 1 of Set 5 | mergui
# City not found. Skipping...
# Processing Record 2 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 4 of Set 5 | carnot
# Processing Record 5 of Set 5 | geraldton
# Processing Record 6 of Set 5 | alofi
# Processing Record 7 of Set 5 | ostrovnoy
# Processing Record 8 of Set 5 | warmbad
# Processing Record 9 of Set 5 | upata
# Processing Record 10 of Set 5 | east london
# Processing Record 11 of Set 5 | belmonte
# Processing Record 12 of Set 5 | tuatapere
# Processing Record 13 of Set 5 | los llanos de aridane
# Processing Record 14 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 15 of Set 5 | taksimo
# Processing Record 16 of Set 5 | severo-kurilsk
# Processing Record 17 of Set 5 | constitucion
# Processing Record 18 of Set 5 | kahului
# Processing Record 19 of Set 5 | sao filipe
# Processing Record 20 of Set 5 | lianran
# Processing Record 21 of Set 5 | necochea
# Processing Record 22 of Set 5 | kamenka
# Processing Record 23 of Set 5 | namibe
# Processing Record 24 of Set 5 | pato branco
# Processing Record 25 of Set 5 | flin flon
# Processing Record 26 of Set 5 | adrar
# Processing Record 27 of Set 5 | tiarei
# Processing Record 28 of Set 5 | zarichne
# Processing Record 29 of Set 5 | harper
# Processing Record 30 of Set 5 | lata
# Processing Record 31 of Set 5 | buraydah
# Processing Record 32 of Set 5 | pevek
# Processing Record 33 of Set 5 | makakilo city
# Processing Record 34 of Set 5 | ginda
# Processing Record 35 of Set 5 | yumen
# Processing Record 36 of Set 5 | horki
# Processing Record 37 of Set 5 | baruun-urt
# Processing Record 38 of Set 5 | toftir
# City not found. Skipping...
# Processing Record 39 of Set 5 | loei
# Processing Record 40 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 5 | sabang
# Processing Record 42 of Set 5 | georgetown
# Processing Record 43 of Set 5 | padang
# Processing Record 44 of Set 5 | pochutla
# Processing Record 45 of Set 5 | port elizabeth
# Processing Record 46 of Set 5 | bocaranga
# City not found. Skipping...
# Processing Record 47 of Set 5 | kashan
# Processing Record 48 of Set 5 | mersing
# Processing Record 49 of Set 5 | dunedin
# Processing Record 50 of Set 5 | himora
# City not found. Skipping...
# Processing Record 1 of Set 6 | ambon
# Processing Record 2 of Set 6 | luganville
# Processing Record 3 of Set 6 | abu dhabi
# Processing Record 4 of Set 6 | andenes
# Processing Record 5 of Set 6 | tamiahua
# Processing Record 6 of Set 6 | rosehearty
# Processing Record 7 of Set 6 | orotukan
# Processing Record 8 of Set 6 | la palma
# Processing Record 9 of Set 6 | kentau
# Processing Record 10 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 6 | hay river
# Processing Record 12 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 13 of Set 6 | teya
# Processing Record 14 of Set 6 | bibiani
# Processing Record 15 of Set 6 | thompson
# Processing Record 16 of Set 6 | tsaratanana
# Processing Record 17 of Set 6 | baykit
# Processing Record 18 of Set 6 | vryheid
# Processing Record 19 of Set 6 | guarapari
# Processing Record 20 of Set 6 | klyuchi
# Processing Record 21 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 22 of Set 6 | avera
# Processing Record 23 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 24 of Set 6 | minab
# Processing Record 25 of Set 6 | tual
# Processing Record 26 of Set 6 | dunnville
# Processing Record 27 of Set 6 | tabat
# Processing Record 28 of Set 6 | vanino
# Processing Record 29 of Set 6 | srednekolymsk
# Processing Record 30 of Set 6 | pattani
# Processing Record 31 of Set 6 | quatre cocos
# Processing Record 32 of Set 6 | poum
# Processing Record 33 of Set 6 | aknada
# Processing Record 34 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 6 | saint-leu
# Processing Record 36 of Set 6 | mogadishu
# Processing Record 37 of Set 6 | ajdabiya
# Processing Record 38 of Set 6 | pocoes
# Processing Record 39 of Set 6 | verkhnevilyuysk
# Processing Record 40 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 41 of Set 6 | bubaque
# Processing Record 42 of Set 6 | rogun
# City not found. Skipping...
# Processing Record 43 of Set 6 | teguise
# Processing Record 44 of Set 6 | buala
# Processing Record 45 of Set 6 | kyra
# Processing Record 46 of Set 6 | kavieng
# Processing Record 47 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 48 of Set 6 | san nicolas
# Processing Record 49 of Set 6 | yertarskiy
# Processing Record 50 of Set 6 | valdivia
# Processing Record 1 of Set 7 | prainha
# Processing Record 2 of Set 7 | tilichiki
# Processing Record 3 of Set 7 | bandarbeyla
# Processing Record 4 of Set 7 | bedesa
# Processing Record 5 of Set 7 | hoquiam
# Processing Record 6 of Set 7 | nevers
# Processing Record 7 of Set 7 | kurilsk
# Processing Record 8 of Set 7 | lagoa
# Processing Record 9 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 10 of Set 7 | atyrau
# Processing Record 11 of Set 7 | bend
# Processing Record 12 of Set 7 | celestun
# Processing Record 13 of Set 7 | roccastrada
# Processing Record 14 of Set 7 | tidore
# City not found. Skipping...
# Processing Record 15 of Set 7 | tiksi
# Processing Record 16 of Set 7 | bilma
# Processing Record 17 of Set 7 | asau
# Processing Record 18 of Set 7 | surt
# Processing Record 19 of Set 7 | port macquarie
# Processing Record 20 of Set 7 | nouadhibou
# Processing Record 21 of Set 7 | inuvik
# Processing Record 22 of Set 7 | matay
# Processing Record 23 of Set 7 | jacksonville
# Processing Record 24 of Set 7 | clarence town
# Processing Record 25 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 7 | vardo
# Processing Record 28 of Set 7 | fukue
# Processing Record 29 of Set 7 | nemuro
# Processing Record 30 of Set 7 | imbituba
# Processing Record 31 of Set 7 | narnaund
# Processing Record 32 of Set 7 | troitsko-pechorsk
# Processing Record 33 of Set 7 | the valley
# Processing Record 34 of Set 7 | whithorn
# Processing Record 35 of Set 7 | brownwood
# Processing Record 36 of Set 7 | coquimbo
# Processing Record 37 of Set 7 | razole
# Processing Record 38 of Set 7 | nabire
# Processing Record 39 of Set 7 | bambanglipuro
# Processing Record 40 of Set 7 | palu
# Processing Record 41 of Set 7 | eidfjord
# Processing Record 42 of Set 7 | torbay
# Processing Record 43 of Set 7 | egvekinot
# Processing Record 44 of Set 7 | denpasar
# Processing Record 45 of Set 7 | aklavik
# Processing Record 46 of Set 7 | unye
# City not found. Skipping...
# Processing Record 47 of Set 7 | erenhot
# Processing Record 48 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 49 of Set 7 | alyangula
# Processing Record 50 of Set 7 | plettenberg bay
# Processing Record 1 of Set 8 | maniitsoq
# Processing Record 2 of Set 8 | manokwari
# Processing Record 3 of Set 8 | alto araguaia
# Processing Record 4 of Set 8 | jibuti
# Processing Record 5 of Set 8 | portales
# Processing Record 6 of Set 8 | kisangani
# Processing Record 7 of Set 8 | alice springs
# Processing Record 8 of Set 8 | caravelas
# Processing Record 9 of Set 8 | gulshat
# City not found. Skipping...
# Processing Record 10 of Set 8 | mount pleasant
# Processing Record 11 of Set 8 | codrington
# Processing Record 12 of Set 8 | veracruz
# Processing Record 13 of Set 8 | port lincoln
# Processing Record 14 of Set 8 | tura
# Processing Record 15 of Set 8 | jakarta
# Processing Record 16 of Set 8 | barrow
# Processing Record 17 of Set 8 | pisco
# Processing Record 18 of Set 8 | hamilton
# Processing Record 19 of Set 8 | chhatak
# Processing Record 20 of Set 8 | yuma
# Processing Record 21 of Set 8 | suifenhe
# Processing Record 22 of Set 8 | ilulissat
# Processing Record 23 of Set 8 | severnoye
# Processing Record 24 of Set 8 | tadine
# Processing Record 25 of Set 8 | kemijarvi
# Processing Record 26 of Set 8 | niitsu
# Processing Record 27 of Set 8 | stokmarknes
# Processing Record 28 of Set 8 | axim
# Processing Record 29 of Set 8 | rudarpur
# Processing Record 30 of Set 8 | tiznit
# Processing Record 31 of Set 8 | batagay-alyta
# Processing Record 32 of Set 8 | atasu
# Processing Record 33 of Set 8 | ellensburg
# Processing Record 34 of Set 8 | cockburn harbour
# City not found. Skipping...
# Processing Record 35 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 8 | bud
# Processing Record 37 of Set 8 | zaoyang
# Processing Record 38 of Set 8 | pechenga
# Processing Record 39 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 8 | gorodovikovsk
# Processing Record 41 of Set 8 | la ronge
# Processing Record 42 of Set 8 | tamandare
# Processing Record 43 of Set 8 | aleksandrovka
# Processing Record 44 of Set 8 | okhtyrka
# Processing Record 45 of Set 8 | aguimes
# Processing Record 46 of Set 8 | bangaon
# Processing Record 47 of Set 8 | marfino
# Processing Record 48 of Set 8 | acajutla
# Processing Record 49 of Set 8 | quang ngai
# Processing Record 50 of Set 8 | monte alegre
# Processing Record 1 of Set 9 | vera cruz
# Processing Record 2 of Set 9 | hofn
# Processing Record 3 of Set 9 | bay roberts
# Processing Record 4 of Set 9 | muborak
# Processing Record 5 of Set 9 | dinar
# Processing Record 6 of Set 9 | christchurch
# Processing Record 7 of Set 9 | tocopilla
# Processing Record 8 of Set 9 | zavetnoye
# Processing Record 9 of Set 9 | sapucai
# Processing Record 10 of Set 9 | borovskoy
# Processing Record 11 of Set 9 | pujili
# Processing Record 12 of Set 9 | port hedland
# Processing Record 13 of Set 9 | tezu
# Processing Record 14 of Set 9 | la libertad
# Processing Record 15 of Set 9 | sarangani
# Processing Record 16 of Set 9 | grand gaube
# Processing Record 17 of Set 9 | nome
# Processing Record 18 of Set 9 | okoneshnikovo
# Processing Record 19 of Set 9 | tessalit
# Processing Record 20 of Set 9 | losinyy
# Processing Record 21 of Set 9 | kargasok
# Processing Record 22 of Set 9 | broome
# Processing Record 23 of Set 9 | kavaratti
# Processing Record 24 of Set 9 | mwingi
# Processing Record 25 of Set 9 | high prairie
# Processing Record 26 of Set 9 | bella vista
# Processing Record 27 of Set 9 | xiaoshi
# Processing Record 28 of Set 9 | porto belo
# Processing Record 29 of Set 9 | bonthe
# Processing Record 30 of Set 9 | kongolo
# Processing Record 31 of Set 9 | paamiut
# Processing Record 32 of Set 9 | komsomolskiy
# Processing Record 33 of Set 9 | scottsburgh
# City not found. Skipping...
# Processing Record 34 of Set 9 | birjand
# Processing Record 35 of Set 9 | oranjemund
# Processing Record 36 of Set 9 | muros
# Processing Record 37 of Set 9 | langham
# Processing Record 38 of Set 9 | korla
# Processing Record 39 of Set 9 | coihaique
# Processing Record 40 of Set 9 | catamarca
# Processing Record 41 of Set 9 | sepuka
# Processing Record 42 of Set 9 | boa vista
# Processing Record 43 of Set 9 | byron bay
# Processing Record 44 of Set 9 | bulaevo
# Processing Record 45 of Set 9 | rebrikha
# Processing Record 46 of Set 9 | mitsamiouli
# Processing Record 47 of Set 9 | walvis bay
# Processing Record 48 of Set 9 | fethiye
# Processing Record 49 of Set 9 | gossaigaon
# Processing Record 50 of Set 9 | ngorongoro
# Processing Record 1 of Set 10 | gondanglegi
# Processing Record 2 of Set 10 | rawson
# Processing Record 3 of Set 10 | namatanai
# Processing Record 4 of Set 10 | poso
# Processing Record 5 of Set 10 | lac du bonnet
# Processing Record 6 of Set 10 | noumea
# Processing Record 7 of Set 10 | sayat
# Processing Record 8 of Set 10 | nsoko
# Processing Record 9 of Set 10 | rudbar
# Processing Record 10 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 11 of Set 10 | bapatla
# Processing Record 12 of Set 10 | turayf
# Processing Record 13 of Set 10 | grindavik
# Processing Record 14 of Set 10 | beira
# Processing Record 15 of Set 10 | miyako
# Processing Record 16 of Set 10 | sungurlu
# Processing Record 17 of Set 10 | azad shahr
# Processing Record 18 of Set 10 | chuy
# Processing Record 19 of Set 10 | agidel
# Processing Record 20 of Set 10 | kungurtug
# Processing Record 21 of Set 10 | paragominas
# Processing Record 22 of Set 10 | kapit
# Processing Record 23 of Set 10 | doha
# Processing Record 24 of Set 10 | warrington
# Processing Record 25 of Set 10 | barcelos
# Processing Record 26 of Set 10 | ust-ishim
# Processing Record 27 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 28 of Set 10 | klaksvik
# Processing Record 29 of Set 10 | marsa matruh
# Processing Record 30 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 31 of Set 10 | xingyi
# Processing Record 32 of Set 10 | smithers
# Processing Record 33 of Set 10 | cockburn town
# Processing Record 34 of Set 10 | gimli
# Processing Record 35 of Set 10 | thai nguyen
# Processing Record 36 of Set 10 | caconda
# Processing Record 37 of Set 10 | opuwo
# Processing Record 38 of Set 10 | nuuk
# Processing Record 39 of Set 10 | burnie
# Processing Record 40 of Set 10 | dmitriyevka
# Processing Record 41 of Set 10 | dongtai
# Processing Record 42 of Set 10 | krasnaya gora
# Processing Record 43 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 10 | tynda
# Processing Record 45 of Set 10 | nadvoitsy
# Processing Record 46 of Set 10 | benghazi
# Processing Record 47 of Set 10 | vao
# Processing Record 48 of Set 10 | anadyr
# Processing Record 49 of Set 10 | ixtapa
# Processing Record 50 of Set 10 | ulladulla
# Processing Record 1 of Set 11 | wahran
# City not found. Skipping...
# Processing Record 2 of Set 11 | merauke
# Processing Record 3 of Set 11 | manitouwadge
# Processing Record 4 of Set 11 | salta
# Processing Record 5 of Set 11 | moba
# Processing Record 6 of Set 11 | matagami
# Processing Record 7 of Set 11 | karasjok
# Processing Record 8 of Set 11 | samba
# Processing Record 9 of Set 11 | peniche
# Processing Record 10 of Set 11 | bahia blanca
# Processing Record 11 of Set 11 | maghama
# City not found. Skipping...
# Processing Record 12 of Set 11 | college
# Processing Record 13 of Set 11 | lahij
# Processing Record 14 of Set 11 | aswan
# Processing Record 15 of Set 11 | zambezi
# Processing Record 16 of Set 11 | boyolangu
# Processing Record 17 of Set 11 | blairmore
# Processing Record 18 of Set 11 | talcahuano
# Processing Record 19 of Set 11 | nanakuli
# Processing Record 20 of Set 11 | gambela
# Processing Record 21 of Set 11 | odessa
# Processing Record 22 of Set 11 | nerchinskiy zavod
# Processing Record 23 of Set 11 | vernon
# Processing Record 24 of Set 11 | abu zabad
# Processing Record 25 of Set 11 | araouane
# Processing Record 26 of Set 11 | natchez
# Processing Record 27 of Set 11 | sorong
# Processing Record 28 of Set 11 | north bend
# Processing Record 29 of Set 11 | cortez
# Processing Record 30 of Set 11 | koping
# Processing Record 31 of Set 11 | ilhabela
# Processing Record 32 of Set 11 | sitka
# Processing Record 33 of Set 11 | kuah
# Processing Record 34 of Set 11 | imperial beach
# Processing Record 35 of Set 11 | brae
# Processing Record 36 of Set 11 | antalaha
# Processing Record 37 of Set 11 | katsiveli
# City not found. Skipping...
# Processing Record 38 of Set 11 | lasa
# Processing Record 39 of Set 11 | champerico
# Processing Record 40 of Set 11 | cootamundra
# Processing Record 41 of Set 11 | santa rosalia
# Processing Record 42 of Set 11 | zhuhai
# Processing Record 43 of Set 11 | nelson bay
# Processing Record 44 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 45 of Set 11 | sankt wendel
# Processing Record 46 of Set 11 | mayo
# Processing Record 47 of Set 11 | shaowu
# Processing Record 48 of Set 11 | lucapa
# Processing Record 49 of Set 11 | wewak
# Processing Record 50 of Set 11 | brodokalmak
# Processing Record 1 of Set 12 | dickinson
# Processing Record 2 of Set 12 | ceyhan
# Processing Record 3 of Set 12 | muisne
# Processing Record 4 of Set 12 | san patricio
# Processing Record 5 of Set 12 | yar-sale
# Processing Record 6 of Set 12 | san ramon
# Processing Record 7 of Set 12 | khasan
# Processing Record 8 of Set 12 | lensk
# Processing Record 9 of Set 12 | ginir
# Processing Record 10 of Set 12 | emerald
# Processing Record 11 of Set 12 | san andres
# Processing Record 12 of Set 12 | minden
# Processing Record 13 of Set 12 | vilyuysk
# Processing Record 14 of Set 12 | lumphat
# Processing Record 15 of Set 12 | konya
# Processing Record 16 of Set 12 | road town
# Processing Record 17 of Set 12 | leh
# Processing Record 18 of Set 12 | kafanchan
# Processing Record 19 of Set 12 | antanifotsy
# Processing Record 20 of Set 12 | cotonou
# Processing Record 21 of Set 12 | trairi
# Processing Record 22 of Set 12 | lat yao
# Processing Record 23 of Set 12 | lazaro cardenas
# Processing Record 24 of Set 12 | whitefish
# Processing Record 25 of Set 12 | macenta
# Processing Record 26 of Set 12 | barra dos coqueiros
# Processing Record 27 of Set 12 | hit
# Processing Record 28 of Set 12 | san quintin
# Processing Record 29 of Set 12 | pacific grove
# Processing Record 30 of Set 12 | dandong
# Processing Record 31 of Set 12 | sovetsk
# Processing Record 32 of Set 12 | khani
# Processing Record 33 of Set 12 | mastic beach
# Processing Record 34 of Set 12 | acaponeta
# Processing Record 35 of Set 12 | ranipur
# Processing Record 36 of Set 12 | ishigaki
# Processing Record 37 of Set 12 | quelimane
# Processing Record 38 of Set 12 | tabas
# Processing Record 39 of Set 12 | kayerkan
# Processing Record 40 of Set 12 | urucui
# Processing Record 41 of Set 12 | paraiso
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Ponta Do Sol  32.6667  -17.1000     55.00        47          28
# 1         Vaini -21.2000 -175.2000     84.20        79          20
# 2      Nenjiang  49.1833  125.2167    -20.07        85           0
# 3        Albany  42.6001  -73.9662     37.00        69         100
# 4    Theunissen -28.4110   26.7011     68.61        78          18
# 5     Nantucket  41.2835  -70.0995     44.60        81          90
# 6       Rikitea -23.1203 -134.9692     77.58        72          77
# 7    Nikolskoye  59.7035   30.7861      5.00        78          75
# 8        Sidney -33.8679  151.2073     73.00        83          75
# 9     Busselton -33.6500  115.3333     60.01        76          37
#
#    Wind Speed Country                 Date
# 0        5.01      PT  2021-01-14 21:34:31
# 1        8.05      TO  2021-01-14 21:37:33
# 2        3.96      CN  2021-01-14 21:41:16
# 3        1.21      US  2021-01-14 21:34:10
# 4        5.59      ZA  2021-01-14 21:41:16
# 5        5.75      US  2021-01-14 21:37:05
# 6       10.13      PF  2021-01-14 21:37:39
# 7        2.24      RU  2021-01-14 21:41:17
# 8        6.91      AU  2021-01-14 21:36:48
# 9        5.01      AU  2021-01-14 21:41:17

# %%
city_data_df=city_data_df[["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed"]]
city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0  Ponta Do Sol      PT  2021-01-14 21:34:31  32.6667  -17.1000     55.00
# 1         Vaini      TO  2021-01-14 21:37:33 -21.2000 -175.2000     84.20
# 2      Nenjiang      CN  2021-01-14 21:41:16  49.1833  125.2167    -20.07
# 3        Albany      US  2021-01-14 21:34:10  42.6001  -73.9662     37.00
# 4    Theunissen      ZA  2021-01-14 21:41:16 -28.4110   26.7011     68.61
# 5     Nantucket      US  2021-01-14 21:37:05  41.2835  -70.0995     44.60
# 6       Rikitea      PF  2021-01-14 21:37:39 -23.1203 -134.9692     77.58
# 7    Nikolskoye      RU  2021-01-14 21:41:17  59.7035   30.7861      5.00
# 8        Sidney      AU  2021-01-14 21:36:48 -33.8679  151.2073     73.00
# 9     Busselton      AU  2021-01-14 21:41:17 -33.6500  115.3333     60.01
#
#    Humidity  Cloudiness  Wind Speed
# 0        47          28        5.01
# 1        79          20        8.05
# 2        85           0        3.96
# 3        69         100        1.21
# 4        78          18        5.59
# 5        81          90        5.75
# 6        72          77       10.13
# 7        78          75        2.24
# 8        83          75        6.91
# 9        76          37        5.01

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Get today's date in seconds.
today = time.strftime("%x")
today
# Out:
# '01/14/21'

# %%
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig2.png")

# Show plot.
plt.show()

# %%
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness "+ time.strftime("%x"))
plt.ylabel("Coudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig3.png")

# Show plot.
plt.show()

# %%
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig4.png")

# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City              Bambous Virieux
# Country                        MU
# Date          2021-01-14 21:37:53
# Lat                      -20.3428
# Lng                       57.7575
# Max Temp                       77
# Humidity                       88
# Cloudiness                     40
# Wind Speed                   9.17
# Name: 13, dtype: object

# %%
city_data_df["Lat"] >= 0
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 533    False
# 534     True
# 535     True
# 536    False
# 537     True
# Name: Lat, Length: 538, dtype: bool

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0  Ponta Do Sol      PT  2021-01-14 21:34:31  32.6667  -17.1000     55.00
# 2      Nenjiang      CN  2021-01-14 21:41:16  49.1833  125.2167    -20.07
# 3        Albany      US  2021-01-14 21:34:10  42.6001  -73.9662     37.00
# 5     Nantucket      US  2021-01-14 21:37:05  41.2835  -70.0995     44.60
# 7    Nikolskoye      RU  2021-01-14 21:41:17  59.7035   30.7861      5.00
#
#    Humidity  Cloudiness  Wind Speed
# 0        47          28        5.01
# 2        85           0        3.96
# 3        69         100        1.21
# 5        81          90        5.75
# 7        78          75        2.24

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,90))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,'Linear Regression on the Southern Hemisphere \n for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for Wind Speed', 'Wind Speed',(-50,35))
